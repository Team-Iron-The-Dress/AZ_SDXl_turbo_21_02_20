# %%
# !pip install modal
# !modal setup
# Out:
# Collecting modal
#   Downloading modal-0.57.41-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.6/374.6 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from modal) (3.9.3)
# Collecting aiostream (from modal)
#   Downloading aiostream-0.5.2-py3-none-any.whl (39 kB)
# Collecting asgiref (from modal)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from modal) (2024.2.2)
# Requirement already satisfied: click>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from modal) (8.1.7)
# Collecting fastapi (from modal)
#   Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 9.9 MB/s eta 0:00:00
# Collecting grpclib==0.4.7 (from modal)
#   Downloading grpclib-0.4.7.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from modal) (7.0.1)
# Requirement already satisfied: protobuf!=4.24.0,<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from modal) (3.20.3)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from modal) (13.7.0)
# Collecting synchronicity~=0.6.2 (from modal)
#   Downloading synchronicity-0.6.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: tblib>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from modal) (3.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from modal) (0.10.2)
# Requirement already satisfied: typer~=0.9.0 in /usr/local/lib/python3.10/dist-packages (from modal) (0.9.0)
# Collecting types-certifi (from modal)
#   Downloading types_certifi-2021.10.8.3-py3-none-any.whl (2.1 kB)
# Collecting types-toml (from modal)
#   Downloading types_toml-0.10.8.7-py3-none-any.whl (4.6 kB)
# Collecting watchfiles (from modal)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions~=4.6 in /usr/local/lib/python3.10/dist-packages (from modal) (4.9.0)
# Collecting cloudpickle<2.1.0,>=2.0.0 (from modal)
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting h2<5,>=3.1.0 (from grpclib==0.4.7->modal)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib==0.4.7->modal) (6.0.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6.0->modal) (3.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->modal) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->modal) (2.16.1)
# Collecting sigtools==4.0.1 (from synchronicity~=0.6.2->modal)
#   Downloading sigtools-4.0.1-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from sigtools==4.0.1->synchronicity~=0.6.2->modal) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal) (4.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi->modal) (2.6.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->modal)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from watchfiles->modal) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles->modal) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles->modal) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles->modal) (1.2.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3.1.0->grpclib==0.4.7->modal)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3.1.0->grpclib==0.4.7->modal)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal) (0.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->modal) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->modal) (2.16.2)
# Building wheels for collected packages: grpclib
#   Building wheel for grpclib (pyproject.toml) ... done
#   Created wheel for grpclib: filename=grpclib-0.4.7-py3-none-any.whl size=76221 sha256=792aaa6c20ec790be1626a3492afa81c5ff2acd26d45310253c7579bfe87269d
#   Stored in directory: /root/.cache/pip/wheels/05/c0/1c/3d807409d0c67efeab2949832ba409205b1b6fe03f739ae4c1
# Successfully built grpclib
# Installing collected packages: types-toml, types-certifi, sigtools, hyperframe, hpack, cloudpickle, asgiref, aiostream, watchfiles, synchronicity, starlette, h2, grpclib, fastapi, modal
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed aiostream-0.5.2 asgiref-3.7.2 cloudpickle-2.0.0 fastapi-0.109.2 grpclib-0.4.7 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 modal-0.57.41 sigtools-4.0.1 starlette-0.36.3 synchronicity-0.6.2 types-certifi-2021.10.8.3 types-toml-0.10.8.7 watchfiles-0.21.0
# Was not able to launch web browser
# Please go to this URL manually and complete the flow:
#
# ]8;id=25817;https://modal.com/token-flow/tf-c1whEil8lfM42GFkTZUqGZ\https://modal.com/token-flow/tf-c1whEil8lfM42GFkTZUqGZ]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠸ Waiting for token flow to complete... (attempt 31)
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/synchronicity/combined_types.py:28 in __call__           │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/modal/cli/entry_point.py:81 in setup                     │
# │                                                                                                  │
# │    80 │   # Fetch a new token (same as `modal token new` but redirect to /home once finishes)    │
# │ ❱  81 │   await _new_token(profile=profile, next_url="/home")                                    │
# │    82                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/modal/token_flow.py:104 in _new_token                    │
# │                                                                                                  │
# │   103 │   │   │   │   for attempt in itertools.count():                                          │
# │ ❱ 104 │   │   │   │   │   result = await token_flow.finish()                                     │
# │   105 │   │   │   │   │   if result is not None:                                                 │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/modal/token_flow.py:58 in finish                         │
# │                                                                                                  │
# │    57 │   │   )                                                                                  │
# │ ❱  58 │   │   resp = await self.stub.TokenFlowWait(req, timeout=(timeout + grpc_extra_timeout)   │
# │    59 │   │   if not resp.timeout:                                                               │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/grpclib/client.py:904 in __call__                        │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/grpclib/client.py:425 in recv_message                    │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/grpclib/client.py:393 in recv_initial_metadata           │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/grpclib/client.py:345 in _raise_for_grpc_status          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# GRPCError: (<Status.PERMISSION_DENIED: 7>, 'Token flow did not complete in time', None)

# %%
# !git clone https://github.com/modal-labs/modal-examples
# !cd modal-examples
# !modal run 06_gpu_and_ml/stable_diffusion/stable_diffusion_xl_turbo.py

# %% [markdown]
# **fine tuning script**
